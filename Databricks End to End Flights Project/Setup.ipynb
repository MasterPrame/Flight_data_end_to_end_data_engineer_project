# %%
# %sql
CREATE VOLUME DataEngineerFlightProject.raw.rawvolume
--Create Managed Volume

# %%
dbutils.fs.mkdirs("/Volumes/dataengineerflightproject/raw/rawvolume/rawdata/flights")
#mkdirs = making directories

# %%
# %sql
CREATE SCHEMA DataEngineerFlightProject.gold
--Create

# %%
# %sql
CREATE VOLUME dataengineerflightproject.gold.goldvolume

# %% [markdown]
# ###Check Before Incremental

# %%
# %sql
SELECT * FROM delta.`/Volumes/DataEngineerFlightProject/bronze/bronzevolume/flights/data`

-- 100

# %%
# %sql
SELECT * FROM delta.`/Volumes/DataEngineerFlightProject/bronze/bronzevolume/customers/data`

-- 200

# %%
# %sql
SELECT * FROM delta.`/Volumes/DataEngineerFlightProject/bronze/bronzevolume/airports/data`

-- 50
